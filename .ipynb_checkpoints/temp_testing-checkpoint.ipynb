# %% [markdown]
# ## Running an example of general segmentation using SAM2
#
# In this example, the model segments everything it finds in the image.

# %%
import os
# if using Apple MPS, fall back to CPU for unsupported ops
os.environ["PYTORCH_ENABLE_MPS_FALLBACK"] = "1"
import numpy as np
import torch
import matplotlib.pyplot as plt
from PIL import Image

# %%
# select the device for computation
if torch.cuda.is_available():
    device = torch.device("cuda")
elif torch.backends.mps.is_available():
    device = torch.device("mps")
else:
    device = torch.device("cpu")
print(f"using device: {device}")

if device.type == "cuda":
    # use bfloat16 for the entire notebook
    torch.autocast("cuda", dtype=torch.bfloat16).__enter__()
    # turn on tfloat32 for Ampere GPUs (https://pytorch.org/docs/stable/notes/cuda.html#tensorfloat-32-tf32-on-ampere-devices)
    if torch.cuda.get_device_properties(0).major >= 8:
        torch.backends.cuda.matmul.allow_tf32 = True
        torch.backends.cudnn.allow_tf32 = True
elif device.type == "mps":
    print(
        "\nSupport for MPS devices is preliminary. SAM 2 is trained with CUDA and might "
        "give numerically different outputs and sometimes degraded performance on MPS. "
        "See e.g. https://github.com/pytorch/pytorch/issues/84936 for a discussion."
    )
# Out:
# using device: cuda

# %% [markdown]
# ### Geting the image from Solafune competition uploaded to my s3 bucket

# %% [markdown]
# # Finetuning by retraining the model with solafune's data

# %%
import numpy as np
import os
import cv2
import s3fs
import json
import rasterio
from shapely.geometry import Polygon
from PIL import Image, ImageDraw

def polygon_to_mask(polygon, width, height):
    mask = Image.new('L', (width, height), 0)
    ImageDraw.Draw(mask).polygon(polygon, outline=1, fill=1)
    return np.array(mask)

def load_image(image_s3_uri):
    """Load an image from S3 and convert it to a NumPy array."""
    with rasterio.open(image_s3_uri) as src:
        image = src.read()
        image = np.moveaxis(image, 0, -1)
        image = image[:, :, :3]  # Assuming only the first 3 bands are needed (R, G, B)
        image_normalized = (image - np.min(image)) / (np.max(image) - np.min(image)) * 255
        image_normalized = image_normalized.astype(np.uint8)
    return image_normalized

def load_annotations(annotation_s3_uri):
    """Load annotations from a JSON file on S3."""
    fs = s3fs.S3FileSystem()
    with fs.open(annotation_s3_uri, 'r') as f:
        return json.load(f)
def load_original_annotations(annotation_s3_uri):
    """Load annotations for a specific image from a JSON file on S3."""
    fs = s3fs.S3FileSystem()
    with fs.open(annotation_s3_uri, 'r') as f:
        data = json.load(f)
    return data
import numpy as np

def select_random_masks(masks, points=None, num_masks=5):
    total_masks = masks.shape[0]
    
    if total_masks <= num_masks:
        # If there are fewer masks than num_masks, return all of them
        return masks, points if points is not None else masks
    
    # Randomly select num_masks indices
    selected_indices = np.random.choice(total_masks, num_masks, replace=False)
    
    # Select the corresponding masks
    selected_masks = masks[selected_indices]
    
    # Select the corresponding points if provided
    selected_points = points[selected_indices] if points is not None else None
    
    return selected_masks, selected_points if selected_points is not None else selected_masks

# %%
def read_batch(data, image_s3_prefix):
    """Read a random image, its annotations, and generate masks and points."""
    # Select a random entry
    entry = data[np.random.randint(len(data))]
    image_filename = entry['file_name']
    image_s3_uri = os.path.join(image_s3_prefix, image_filename)
    
    # Load image
    Img = load_image(image_s3_uri)
    height, width = Img.shape[:2]
    
    # Load annotations
    annotations = entry['annotations']
    
    # Prepare masks and points
    masks = []
    points = []
    for annotation in annotations:
        mask = polygon_to_mask(annotation['segmentation'], width, height)
        masks.append(mask)
        
        # Generate a random point inside the mask
        coords = np.argwhere(mask > 0)
        yx = coords[np.random.randint(len(coords))]
        points.append([[yx[1], yx[0]]])

    # No need to convert to tensors here
    return Img, np.array(masks), np.array(points), np.ones([len(masks), 1])

# %%
def read_reduced_batch(data, image_s3_prefix, num_annotations=5):
    """Read a random image, its annotations, and generate masks and points with a reduced number of annotations."""
    # Select a random entry
    entry = data[np.random.randint(len(data))]
    image_filename = entry['file_name']
    image_s3_uri = os.path.join(image_s3_prefix, image_filename)
    
    # Load image
    Img = load_image(image_s3_uri)
    height, width = Img.shape[:2]
    
    # Load annotations
    annotations = entry['annotations']
    
    # Randomly select up to num_annotations from the available annotations
    if len(annotations) > num_annotations:
        selected_annotations = np.random.choice(annotations, num_annotations, replace=False)
    else:
        selected_annotations = annotations
    
    # Prepare masks and points
    masks = []
    points = []
    for annotation in selected_annotations:
        mask = polygon_to_mask(annotation['segmentation'], width, height)
        masks.append(mask)
        
        # Generate a random point inside the mask
        coords = np.argwhere(mask > 0)
        yx = coords[np.random.randint(len(coords))]
        points.append([[yx[1], yx[0]]])

    # No need to convert to tensors here
    return Img, np.array(masks), np.array(points), np.ones([len(masks), 1])

# %%
# Load Json
import s3fs
import json
train_annotation_s3_uri = 's3://solafune/train_annotation.json'

from torch.utils.data import DataLoader

# List of image filenames
image_filenames = [img['file_name'] for img in load_original_annotations(train_annotation_s3_uri)['images']]

#image_filenames = ['train_28.tif'] # set a quick training with specific images
image_s3_prefix = 's3://solafune/train_images/images'

# %%
import matplotlib.pyplot as plt


def visualize_batch(image, masks, points=None):
    print(f" - Image shape : {image.shape}")
    print(f" - Masks shape: {masks.shape}")
    
    plt.figure(figsize=(12, 6))
    
    # Show the image
    plt.subplot(1, 2, 1)
    plt.imshow(image)
    plt.title("Image")
    plt.axis('off')
    
    # Show the masks overlayed on the image
    combined_mask = masks.sum(axis=0)
    plt.subplot(1, 2, 2)
    plt.imshow(image)
    plt.imshow(combined_mask, alpha=0.5, cmap='jet')
    
    # Plot the points if provided
    if points is not None:
        for point in points:
            plt.plot(point[0][0], point[0][1], 'ro')  # red dots for points
    
    plt.title("Masks Overlay with Points")
    plt.axis('off')
    
    plt.show()



# Load the annotations data
data = load_annotations(train_annotation_s3_uri)['images']

image, masks, points, _ = read_batch(data, image_s3_prefix)


# Visualize the batch
visualize_batch(image, masks)

image, masks, points, _ = read_reduced_batch(data, image_s3_prefix)


visualize_batch(image, masks, points)
# Out:
#  - Image shape : (803, 1039, 3)
#  - Masks shape: (2973, 803, 1039)
#  - Image shape : (804, 976, 3)
#  - Masks shape: (5, 804, 976)

# %% [markdown]
# # Main Train Loop

# %%
# Load model
from sam2.build_sam import build_sam2
from sam2.automatic_mask_generator import SAM2AutomaticMaskGenerator
from sam2.sam2_image_predictor import SAM2ImagePredictor

sam2_checkpoint = "./segment-anything-2/checkpoints/sam2_hiera_large.pt"  # path to model weight
model_cfg = "sam2_hiera_l.yaml"  # model config
sam2_model = build_sam2(model_cfg, sam2_checkpoint, device="cuda")  # load model
predictor = SAM2ImagePredictor(sam2_model)

#If saved
# saved_state = torch.load("model_large.torch")
# predictor.model.load_state_dict(saved_state)

# Set training parameters

predictor.model.sam_mask_decoder.train(True)  # enable training of mask decoder
predictor.model.sam_prompt_encoder.train(True)  # enable training of prompt encoder
optimizer = torch.optim.AdamW(params=predictor.model.parameters(), lr=1e-5, weight_decay=4e-5)
scaler = torch.cuda.amp.GradScaler()  # mixed precision

# %%
def check_weight_updates(model, old_state_dict):
    updated = False
    for name, param in model.named_parameters():
        if not torch.equal(param.data, old_state_dict[name].data):
            updated = True
            break
    return updated

# %%
# Training loop

for itr in range(100000):
    with torch.cuda.amp.autocast():  # cast to mix precision
        # Use the custom read_batch function
        image, mask, input_point, input_label = read_reduced_batch(data, image_s3_prefix)  # in a better computer you can run for all the masks

        if mask.shape[0] == 0: continue  # ignore empty batches

        predictor.set_image(image)  # apply SAM image encoder to the image

        # prompt encoding
        mask_input, unnorm_coords, labels, unnorm_box = predictor._prep_prompts(
            input_point, input_label, box=None, mask_logits=None, normalize_coords=True
        )
        sparse_embeddings, dense_embeddings = predictor.model.sam_prompt_encoder(
            points=(unnorm_coords, labels), boxes=None, masks=None,
        )

        # mask decoder
        batched_mode = unnorm_coords.shape[0] > 1  # multi object prediction
        high_res_features = [feat_level[-1].unsqueeze(0) for feat_level in predictor._features["high_res_feats"]]
        low_res_masks, prd_scores, _, _ = predictor.model.sam_mask_decoder(
            image_embeddings=predictor._features["image_embed"][-1].unsqueeze(0),
            image_pe=predictor.model.sam_prompt_encoder.get_dense_pe(),
            sparse_prompt_embeddings=sparse_embeddings,
            dense_prompt_embeddings=dense_embeddings,
            multimask_output=True,
            repeat_image=batched_mode,
            high_res_features=high_res_features,
        )
        prd_masks = predictor._transforms.postprocess_masks(
            low_res_masks, predictor._orig_hw[-1]
        )  # Upscale the masks to the original image resolution

        # Segmentation Loss calculation
        gt_mask = torch.tensor(mask.astype(np.float32)).cuda()
        prd_mask = torch.sigmoid(prd_masks[:, 0])  # Turn logit map to probability map
        seg_loss = (
            -gt_mask * torch.log(prd_mask + 0.00001)
            - (1 - gt_mask) * torch.log((1 - prd_mask) + 0.00001)
        ).mean()  # cross entropy loss

        # Score loss calculation (intersection over union) IOU
        inter = (gt_mask * (prd_mask > 0.5)).sum(1).sum(1)
        iou = inter / (gt_mask.sum(1).sum(1) + (prd_mask > 0.5).sum(1).sum(1) - inter)
        score_loss = torch.abs(prd_scores[:, 0] - iou).mean()
        loss = seg_loss + score_loss * 0.05  # mix losses

        # Save model's current state_dict before the update
        if itr % 1000 == 0:
            old_state_dict = {name: param.clone() for name, param in predictor.model.named_parameters()}

        # apply backpropagation
        predictor.model.zero_grad()  # empty gradient
        scaler.scale(loss).backward()  # Backpropagate
        scaler.step(optimizer)
        scaler.update()  # Mix precision

        # Check if weights have been updated
        if itr % 1000 == 0:
            if check_weight_updates(predictor.model, old_state_dict):
                    print(f"Iteration {itr}: Weights have been updated.")
            else:
                    print(f"Iteration {itr}: No weight updates detected.")

        if itr % 1000 == 0: 
            torch.save(predictor.model.state_dict(), "model.torch")
            print("Model saved.")

        # Display results
        if itr == 0: 
            mean_iou = 0
        mean_iou = mean_iou * 0.99 + 0.01 * np.mean(iou.cpu().detach().numpy())
        print(f"step {itr} Accuracy(IOU)= {mean_iou:.8f}")
# Out:
# Iteration 0: Weights have been updated.
# Model saved.
# step 0 Accuracy(IOU)= 0.00029156
# step 1 Accuracy(IOU)= 0.00687417
# step 2 Accuracy(IOU)= 0.00979572
# step 3 Accuracy(IOU)= 0.01120439
# step 4 Accuracy(IOU)= 0.01787430
# step 5 Accuracy(IOU)= 0.02400235
# step 6 Accuracy(IOU)= 0.03289019
# step 7 Accuracy(IOU)= 0.04027220
# step 8 Accuracy(IOU)= 0.04641215
# step 9 Accuracy(IOU)= 0.05300135
# step 10 Accuracy(IOU)= 0.05599562
# step 11 Accuracy(IOU)= 0.05571440
# step 12 Accuracy(IOU)= 0.05785351
# step 13 Accuracy(IOU)= 0.05957951
# step 14 Accuracy(IOU)= 0.06424029
# step 15 Accuracy(IOU)= 0.07006607
# step 16 Accuracy(IOU)= 0.07283913
# /tmp/ipykernel_7466/2493433692.py:22: RuntimeWarning: invalid value encountered in cast
#   image_normalized = image_normalized.astype(np.uint8)
# step 17 Accuracy(IOU)= 0.07365953
# step 18 Accuracy(IOU)= 0.07938031
# step 19 Accuracy(IOU)= 0.08436776
# step 20 Accuracy(IOU)= 0.08780354
# step 21 Accuracy(IOU)= 0.09496804
# step 22 Accuracy(IOU)= 0.09790447
# step 23 Accuracy(IOU)= 0.10160429
# step 24 Accuracy(IOU)= 0.10616441
# step 25 Accuracy(IOU)= 0.10831610
# step 26 Accuracy(IOU)= 0.11028661
# step 27 Accuracy(IOU)= 0.11519319
# step 28 Accuracy(IOU)= 0.11855484
# step 29 Accuracy(IOU)= 0.11976635
# step 30 Accuracy(IOU)= 0.12289432
# step 31 Accuracy(IOU)= 0.12483348
# step 32 Accuracy(IOU)= 0.12859573
# step 33 Accuracy(IOU)= 0.12935283
# step 34 Accuracy(IOU)= 0.13383566
# step 35 Accuracy(IOU)= 0.13627402
# step 36 Accuracy(IOU)= 0.13900261
# step 37 Accuracy(IOU)= 0.14035317
# step 38 Accuracy(IOU)= 0.14272742
# step 39 Accuracy(IOU)= 0.14203367
# step 40 Accuracy(IOU)= 0.14534209
# step 41 Accuracy(IOU)= 0.14621181
# step 42 Accuracy(IOU)= 0.14651247
# step 43 Accuracy(IOU)= 0.14791806
# step 44 Accuracy(IOU)= 0.14832648
# step 45 Accuracy(IOU)= 0.14920619
# step 46 Accuracy(IOU)= 0.15143519
# step 47 Accuracy(IOU)= 0.15190104
# step 48 Accuracy(IOU)= 0.15383943
# step 49 Accuracy(IOU)= 0.15816090
# step 50 Accuracy(IOU)= 0.15681106
# step 51 Accuracy(IOU)= 0.15903740
# step 52 Accuracy(IOU)= 0.16464972
# step 53 Accuracy(IOU)= 0.16914062
# step 54 Accuracy(IOU)= 0.16953811
# step 55 Accuracy(IOU)= 0.16989578
# step 56 Accuracy(IOU)= 0.16910100
# step 57 Accuracy(IOU)= 0.17554624
# step 58 Accuracy(IOU)= 0.17433594
# step 59 Accuracy(IOU)= 0.17449401
# step 60 Accuracy(IOU)= 0.17488713
# step 61 Accuracy(IOU)= 0.17717281
# step 62 Accuracy(IOU)= 0.17814851
# step 63 Accuracy(IOU)= 0.18174914
# step 64 Accuracy(IOU)= 0.18119466
# step 65 Accuracy(IOU)= 0.18332049
# step 66 Accuracy(IOU)= 0.18802519
# step 67 Accuracy(IOU)= 0.19102479
# step 68 Accuracy(IOU)= 0.18991769
# step 69 Accuracy(IOU)= 0.18859858
# step 70 Accuracy(IOU)= 0.19165044
# step 71 Accuracy(IOU)= 0.19871680
# step 72 Accuracy(IOU)= 0.20232274
# step 73 Accuracy(IOU)= 0.20671435
# step 74 Accuracy(IOU)= 0.21296423
# step 75 Accuracy(IOU)= 0.21291550
# step 76 Accuracy(IOU)= 0.21803175
# step 77 Accuracy(IOU)= 0.22378771
# step 78 Accuracy(IOU)= 0.22327315
# step 79 Accuracy(IOU)= 0.22223809
# step 80 Accuracy(IOU)= 0.22604145
# step 81 Accuracy(IOU)= 0.22766851
# step 82 Accuracy(IOU)= 0.22996721
# step 83 Accuracy(IOU)= 0.23029096
# step 84 Accuracy(IOU)= 0.23422830
# step 85 Accuracy(IOU)= 0.23456477
# step 86 Accuracy(IOU)= 0.24030588
# step 87 Accuracy(IOU)= 0.24472266
# step 88 Accuracy(IOU)= 0.24474676
# step 89 Accuracy(IOU)= 0.24510225
# step 90 Accuracy(IOU)= 0.24381588
# step 91 Accuracy(IOU)= 0.24321595
# step 92 Accuracy(IOU)= 0.24477913
# step 93 Accuracy(IOU)= 0.24302151
# step 94 Accuracy(IOU)= 0.24290437
# step 95 Accuracy(IOU)= 0.24393497
# step 96 Accuracy(IOU)= 0.24238538
# step 97 Accuracy(IOU)= 0.24506999
# step 98 Accuracy(IOU)= 0.24704043
# step 99 Accuracy(IOU)= 0.24707536
# step 100 Accuracy(IOU)= 0.24659700
# step 101 Accuracy(IOU)= 0.24691522
# step 102 Accuracy(IOU)= 0.24508882
# step 103 Accuracy(IOU)= 0.24909337
# step 104 Accuracy(IOU)= 0.24966639
# step 105 Accuracy(IOU)= 0.25108779
# step 106 Accuracy(IOU)= 0.24909613
# step 107 Accuracy(IOU)= 0.25187773
# step 108 Accuracy(IOU)= 0.25411022
# step 109 Accuracy(IOU)= 0.25788907
# step 110 Accuracy(IOU)= 0.25559886
# step 111 Accuracy(IOU)= 0.26085114
# step 112 Accuracy(IOU)= 0.26485005
# step 113 Accuracy(IOU)= 0.26798877
# step 114 Accuracy(IOU)= 0.26853006
# step 115 Accuracy(IOU)= 0.26864570
# step 116 Accuracy(IOU)= 0.27477342
# step 117 Accuracy(IOU)= 0.27530200
# step 118 Accuracy(IOU)= 0.27513580
# step 119 Accuracy(IOU)= 0.27805210
# step 120 Accuracy(IOU)= 0.27936535
# step 121 Accuracy(IOU)= 0.28495166
# step 122 Accuracy(IOU)= 0.28277622
# step 123 Accuracy(IOU)= 0.28030399
# step 124 Accuracy(IOU)= 0.28055621
# step 125 Accuracy(IOU)= 0.28048583
# step 126 Accuracy(IOU)= 0.27929146
# step 127 Accuracy(IOU)= 0.27748379
# step 128 Accuracy(IOU)= 0.28121764
# step 129 Accuracy(IOU)= 0.27983218
# step 130 Accuracy(IOU)= 0.28132012
# step 131 Accuracy(IOU)= 0.28084426
# step 132 Accuracy(IOU)= 0.28339557
# step 133 Accuracy(IOU)= 0.28355592
# step 134 Accuracy(IOU)= 0.28894794
# step 135 Accuracy(IOU)= 0.28778633
# step 136 Accuracy(IOU)= 0.29247216
# step 137 Accuracy(IOU)= 0.29389532
# step 138 Accuracy(IOU)= 0.29375880
# step 139 Accuracy(IOU)= 0.29494902
# step 140 Accuracy(IOU)= 0.29831944
# step 141 Accuracy(IOU)= 0.30211611
# step 142 Accuracy(IOU)= 0.30112040
# step 143 Accuracy(IOU)= 0.29861737
# step 144 Accuracy(IOU)= 0.29674315
# step 145 Accuracy(IOU)= 0.30252918
# step 146 Accuracy(IOU)= 0.30647531
# step 147 Accuracy(IOU)= 0.30804540
# step 148 Accuracy(IOU)= 0.31229458
# step 149 Accuracy(IOU)= 0.31420430
# step 150 Accuracy(IOU)= 0.31302635
# step 151 Accuracy(IOU)= 0.31463205
# step 152 Accuracy(IOU)= 0.31293533
# step 153 Accuracy(IOU)= 0.31039292
# step 154 Accuracy(IOU)= 0.31023979
# step 155 Accuracy(IOU)= 0.31353174
# step 156 Accuracy(IOU)= 0.31320329
# step 157 Accuracy(IOU)= 0.31333081
# step 158 Accuracy(IOU)= 0.31183558
# step 159 Accuracy(IOU)= 0.31774867
# step 160 Accuracy(IOU)= 0.32004270
# step 161 Accuracy(IOU)= 0.32452082
# step 162 Accuracy(IOU)= 0.32251006
# step 163 Accuracy(IOU)= 0.32298428
# step 164 Accuracy(IOU)= 0.32141164
# step 165 Accuracy(IOU)= 0.32219210
# step 166 Accuracy(IOU)= 0.32242029
# step 167 Accuracy(IOU)= 0.31984702
# step 168 Accuracy(IOU)= 0.31804639
# step 169 Accuracy(IOU)= 0.32205989
# step 170 Accuracy(IOU)= 0.32613638
# step 171 Accuracy(IOU)= 0.32564125
# step 172 Accuracy(IOU)= 0.32393133
# step 173 Accuracy(IOU)= 0.32648590
# step 174 Accuracy(IOU)= 0.32595116
# step 175 Accuracy(IOU)= 0.33065594
# step 176 Accuracy(IOU)= 0.33259960
# step 177 Accuracy(IOU)= 0.33076071
# step 178 Accuracy(IOU)= 0.32885140
# step 179 Accuracy(IOU)= 0.33016153
# step 180 Accuracy(IOU)= 0.32871095
# step 181 Accuracy(IOU)= 0.33012394
# step 182 Accuracy(IOU)= 0.32983380
# step 183 Accuracy(IOU)= 0.32740351
# step 184 Accuracy(IOU)= 0.32759987
# step 185 Accuracy(IOU)= 0.32845197
# step 186 Accuracy(IOU)= 0.32752229
# step 187 Accuracy(IOU)= 0.33221562
# step 188 Accuracy(IOU)= 0.33350746
# step 189 Accuracy(IOU)= 0.33148846
# step 190 Accuracy(IOU)= 0.32882373
# step 191 Accuracy(IOU)= 0.33248249
# step 192 Accuracy(IOU)= 0.33324517
# step 193 Accuracy(IOU)= 0.33420617
# step 194 Accuracy(IOU)= 0.33996261
# step 195 Accuracy(IOU)= 0.34053733
# step 196 Accuracy(IOU)= 0.34313082
# step 197 Accuracy(IOU)= 0.34274431
# step 198 Accuracy(IOU)= 0.33982645
# step 199 Accuracy(IOU)= 0.34383097
# step 200 Accuracy(IOU)= 0.34771310
# step 201 Accuracy(IOU)= 0.34520410
# step 202 Accuracy(IOU)= 0.34417731
# step 203 Accuracy(IOU)= 0.34436260
# step 204 Accuracy(IOU)= 0.34642967
# step 205 Accuracy(IOU)= 0.34660975
# step 206 Accuracy(IOU)= 0.35021256
# step 207 Accuracy(IOU)= 0.34968701
# step 208 Accuracy(IOU)= 0.35015264
# step 209 Accuracy(IOU)= 0.34930440
# step 210 Accuracy(IOU)= 0.35308755
# step 211 Accuracy(IOU)= 0.35510139
# step 212 Accuracy(IOU)= 0.35616429
# step 213 Accuracy(IOU)= 0.36080846
# step 214 Accuracy(IOU)= 0.35872879
# step 215 Accuracy(IOU)= 0.35805168
# step 216 Accuracy(IOU)= 0.35827533
# step 217 Accuracy(IOU)= 0.35687273
# step 218 Accuracy(IOU)= 0.35596634
# step 219 Accuracy(IOU)= 0.35605195
# step 220 Accuracy(IOU)= 0.35677524
# step 221 Accuracy(IOU)= 0.35571999
# step 222 Accuracy(IOU)= 0.35884071
# step 223 Accuracy(IOU)= 0.35909072
# step 224 Accuracy(IOU)= 0.35946789
# step 225 Accuracy(IOU)= 0.36291658
# step 226 Accuracy(IOU)= 0.36277579
# step 227 Accuracy(IOU)= 0.36165817
# step 228 Accuracy(IOU)= 0.36400342
# step 229 Accuracy(IOU)= 0.36168509
# step 230 Accuracy(IOU)= 0.36280496
# step 231 Accuracy(IOU)= 0.35989510
# step 232 Accuracy(IOU)= 0.36073943
# step 233 Accuracy(IOU)= 0.35911048
# step 234 Accuracy(IOU)= 0.35877742
# step 235 Accuracy(IOU)= 0.35752153
# step 236 Accuracy(IOU)= 0.36023276
# step 237 Accuracy(IOU)= 0.36300068
# step 238 Accuracy(IOU)= 0.36153317
# step 239 Accuracy(IOU)= 0.36324913
# step 240 Accuracy(IOU)= 0.36431568
# step 241 Accuracy(IOU)= 0.36751538
# step 242 Accuracy(IOU)= 0.36839582
# step 243 Accuracy(IOU)= 0.36575598
# step 244 Accuracy(IOU)= 0.36402723
# step 245 Accuracy(IOU)= 0.36100533
# step 246 Accuracy(IOU)= 0.36243350
# step 247 Accuracy(IOU)= 0.36050442
# step 248 Accuracy(IOU)= 0.36129582
# step 249 Accuracy(IOU)= 0.36392127
# step 250 Accuracy(IOU)= 0.36307925
# step 251 Accuracy(IOU)= 0.36568615
# step 252 Accuracy(IOU)= 0.36836088
# step 253 Accuracy(IOU)= 0.37093980
# step 254 Accuracy(IOU)= 0.37277087
# step 255 Accuracy(IOU)= 0.37494808
# step 256 Accuracy(IOU)= 0.37570651
# step 257 Accuracy(IOU)= 0.37862046
# step 258 Accuracy(IOU)= 0.37668622
# step 259 Accuracy(IOU)= 0.37759291
# step 260 Accuracy(IOU)= 0.37546309

# %%
torch.save(predictor.model.state_dict(), "model.torch")

# %% [markdown]
# ## Test the results

# %%
import matplotlib.pyplot as plt
import torch
import numpy as np

# Function to calculate IoU between two masks
def calculate_iou(gt_mask, pred_mask):
    inter = (gt_mask & pred_mask).sum()
    union = (gt_mask | pred_mask).sum()
    iou = inter / (union + 1e-5)
    return iou.item()

# Function to visualize the image, GT mask, and predicted masks from different models
def visualize_image_and_masks(image, gt_mask, prd_mask_saved, prd_mask_checkpoint, point):
    plt.figure(figsize=(20, 4))

    # Plot image with random point
    plt.subplot(1, 4, 1)
    plt.imshow(image)
    plt.scatter(point[0], point[1], color='red')
    plt.title("Image with Random Point")

    # Plot GT mask
    plt.subplot(1, 4, 2)
    plt.imshow(gt_mask, cmap='gray')
    plt.title("Ground Truth Mask")

    # Plot Predicted mask (Current saved state)
    plt.subplot(1, 4, 3)
    plt.imshow(prd_mask_saved, cmap='gray')
    plt.title("Current Saved State")

    # Plot Predicted mask (SAM2 checkpoint)
    plt.subplot(1, 4, 4)
    plt.imshow(prd_mask_checkpoint, cmap='gray')
    plt.title("SAM2 Checkpoint")

    plt.show()

# Test the read_batch function and visualize the result
image, mask, input_point, input_label = read_reduced_batch(data, image_s3_prefix)

# Use the first point in the batch
input_point = np.array([[500, 375]])
input_label = np.array([1])



# 2. Load the SAM2 checkpoint and predict
sam2_checkpoint = "./segment-anything-2/checkpoints/sam2_hiera_large.pt"  # Adjust to large if needed
model_cfg = "sam2_hiera_l.yaml"  # Adjust to large if needed
sam2_model = build_sam2(model_cfg, sam2_checkpoint, device="cuda")
predictor = SAM2ImagePredictor(sam2_model)
predictor.set_image(image)
masks_pred_checkpoint, _, _ = predictor.predict(
    point_coords=input_point,
    point_labels=input_label,
    multimask_output=False
)
prd_mask_checkpoint = masks_pred_checkpoint[0].astype(np.uint8)

# 1. Load the saved model state and predict
# use bfloat16 for the entire script (memory efficient)
torch.autocast(device_type="cuda", dtype=torch.bfloat16).__enter__()

saved_state = torch.load("model_large.torch")
predictor.model.load_state_dict(saved_state)

with torch.no_grad(): # prevent the net from caclulate gradient (more efficient inference)
        predictor.set_image(image) # image encoder
            # Use the first point in the batch
        input_points = np.array([[500, 375]])
        input_labels = np.array([1])
        masks_pred_saved, _, _ = predictor.predict(
            point_coords=input_point,
            point_labels=input_label,
            multimask_output=False
        )
        prd_mask_saved = masks_pred_saved[0].astype(np.uint8)
      

# Convert ground truth mask to binary
gt_mask = masks[0].astype(np.uint8)

# # Calculate IoU
# iou_saved_state = calculate_iou(gt_mask, prd_mask_saved)
# iou_checkpoint = calculate_iou(gt_mask, prd_mask_checkpoint)

# print(f"IoU (Current Saved State): {iou_saved_state:.4f}")
# print(f"IoU (SAM2 Checkpoint): {iou_checkpoint:.4f}")

# Visualize all the results
visualize_image_and_masks(image, gt_mask, prd_mask_saved, prd_mask_checkpoint, input_points[0])

# %% [markdown]
# ## Running an example of general segmentation using SAM2
#
# In this example, the model segments everything it finds in the image.

# %%
import os
# if using Apple MPS, fall back to CPU for unsupported ops
os.environ["PYTORCH_ENABLE_MPS_FALLBACK"] = "1"
import numpy as np
import torch
import matplotlib.pyplot as plt
from PIL import Image

# %%
# select the device for computation
if torch.cuda.is_available():
    device = torch.device("cuda")
elif torch.backends.mps.is_available():
    device = torch.device("mps")
else:
    device = torch.device("cpu")
print(f"using device: {device}")

if device.type == "cuda":
    # use bfloat16 for the entire notebook
    torch.autocast("cuda", dtype=torch.bfloat16).__enter__()
    # turn on tfloat32 for Ampere GPUs (https://pytorch.org/docs/stable/notes/cuda.html#tensorfloat-32-tf32-on-ampere-devices)
    if torch.cuda.get_device_properties(0).major >= 8:
        torch.backends.cuda.matmul.allow_tf32 = True
        torch.backends.cudnn.allow_tf32 = True
elif device.type == "mps":
    print(
        "\nSupport for MPS devices is preliminary. SAM 2 is trained with CUDA and might "
        "give numerically different outputs and sometimes degraded performance on MPS. "
        "See e.g. https://github.com/pytorch/pytorch/issues/84936 for a discussion."
    )
# Out:
# using device: cuda

# %% [markdown]
# ### Geting the image from Solafune competition uploaded to my s3 bucket

# %% [markdown]
# # Finetuning by retraining the model with solafune's data

# %%
import numpy as np
import os
import cv2
import s3fs
import json
import rasterio
from shapely.geometry import Polygon
from PIL import Image, ImageDraw

def polygon_to_mask(polygon, width, height):
    mask = Image.new('L', (width, height), 0)
    ImageDraw.Draw(mask).polygon(polygon, outline=1, fill=1)
    return np.array(mask)

def load_image(image_s3_uri):
    """Load an image from S3 and convert it to a NumPy array."""
    with rasterio.open(image_s3_uri) as src:
        image = src.read()
        image = np.moveaxis(image, 0, -1)
        image = image[:, :, :3]  # Assuming only the first 3 bands are needed (R, G, B)
        image_normalized = (image - np.min(image)) / (np.max(image) - np.min(image)) * 255
        image_normalized = image_normalized.astype(np.uint8)
    return image_normalized

def load_annotations(annotation_s3_uri):
    """Load annotations from a JSON file on S3."""
    fs = s3fs.S3FileSystem()
    with fs.open(annotation_s3_uri, 'r') as f:
        return json.load(f)
def load_original_annotations(annotation_s3_uri):
    """Load annotations for a specific image from a JSON file on S3."""
    fs = s3fs.S3FileSystem()
    with fs.open(annotation_s3_uri, 'r') as f:
        data = json.load(f)
    return data
import numpy as np

def select_random_masks(masks, points=None, num_masks=5):
    total_masks = masks.shape[0]
    
    if total_masks <= num_masks:
        # If there are fewer masks than num_masks, return all of them
        return masks, points if points is not None else masks
    
    # Randomly select num_masks indices
    selected_indices = np.random.choice(total_masks, num_masks, replace=False)
    
    # Select the corresponding masks
    selected_masks = masks[selected_indices]
    
    # Select the corresponding points if provided
    selected_points = points[selected_indices] if points is not None else None
    
    return selected_masks, selected_points if selected_points is not None else selected_masks

# %%
def read_batch(data, image_s3_prefix):
    """Read a random image, its annotations, and generate masks and points."""
    # Select a random entry
    entry = data[np.random.randint(len(data))]
    image_filename = entry['file_name']
    image_s3_uri = os.path.join(image_s3_prefix, image_filename)
    
    # Load image
    Img = load_image(image_s3_uri)
    height, width = Img.shape[:2]
    
    # Load annotations
    annotations = entry['annotations']
    
    # Prepare masks and points
    masks = []
    points = []
    for annotation in annotations:
        mask = polygon_to_mask(annotation['segmentation'], width, height)
        masks.append(mask)
        
        # Generate a random point inside the mask
        coords = np.argwhere(mask > 0)
        yx = coords[np.random.randint(len(coords))]
        points.append([[yx[1], yx[0]]])

    # No need to convert to tensors here
    return Img, np.array(masks), np.array(points), np.ones([len(masks), 1])

# %%
def read_reduced_batch(data, image_s3_prefix, num_annotations=5):
    """Read a random image, its annotations, and generate masks and points with a reduced number of annotations."""
    # Select a random entry
    entry = data[np.random.randint(len(data))]
    image_filename = entry['file_name']
    image_s3_uri = os.path.join(image_s3_prefix, image_filename)
    
    # Load image
    Img = load_image(image_s3_uri)
    height, width = Img.shape[:2]
    
    # Load annotations
    annotations = entry['annotations']
    
    # Randomly select up to num_annotations from the available annotations
    if len(annotations) > num_annotations:
        selected_annotations = np.random.choice(annotations, num_annotations, replace=False)
    else:
        selected_annotations = annotations
    
    # Prepare masks and points
    masks = []
    points = []
    for annotation in selected_annotations:
        mask = polygon_to_mask(annotation['segmentation'], width, height)
        masks.append(mask)
        
        # Generate a random point inside the mask
        coords = np.argwhere(mask > 0)
        yx = coords[np.random.randint(len(coords))]
        points.append([[yx[1], yx[0]]])

    # No need to convert to tensors here
    return Img, np.array(masks), np.array(points), np.ones([len(masks), 1])

# %%
# Load Json
import s3fs
import json
train_annotation_s3_uri = 's3://solafune/train_annotation.json'

from torch.utils.data import DataLoader

# List of image filenames
image_filenames = [img['file_name'] for img in load_original_annotations(train_annotation_s3_uri)['images']]

#image_filenames = ['train_28.tif'] # set a quick training with specific images
image_s3_prefix = 's3://solafune/train_images/images'

# %%
import matplotlib.pyplot as plt


def visualize_batch(image, masks, points=None):
    print(f" - Image shape : {image.shape}")
    print(f" - Masks shape: {masks.shape}")
    
    plt.figure(figsize=(12, 6))
    
    # Show the image
    plt.subplot(1, 2, 1)
    plt.imshow(image)
    plt.title("Image")
    plt.axis('off')
    
    # Show the masks overlayed on the image
    combined_mask = masks.sum(axis=0)
    plt.subplot(1, 2, 2)
    plt.imshow(image)
    plt.imshow(combined_mask, alpha=0.5, cmap='jet')
    
    # Plot the points if provided
    if points is not None:
        for point in points:
            plt.plot(point[0][0], point[0][1], 'ro')  # red dots for points
    
    plt.title("Masks Overlay with Points")
    plt.axis('off')
    
    plt.show()



# Load the annotations data
data = load_annotations(train_annotation_s3_uri)['images']

image, masks, points, _ = read_batch(data, image_s3_prefix)


# Visualize the batch
visualize_batch(image, masks)

image, masks, points, _ = read_reduced_batch(data, image_s3_prefix)


visualize_batch(image, masks, points)
# Out:
#  - Image shape : (803, 1039, 3)
#  - Masks shape: (2973, 803, 1039)
#  - Image shape : (804, 976, 3)
#  - Masks shape: (5, 804, 976)

# %% [markdown]
# # Main Train Loop

# %%
# Load model
from sam2.build_sam import build_sam2
from sam2.automatic_mask_generator import SAM2AutomaticMaskGenerator
from sam2.sam2_image_predictor import SAM2ImagePredictor

sam2_checkpoint = "./segment-anything-2/checkpoints/sam2_hiera_large.pt"  # path to model weight
model_cfg = "sam2_hiera_l.yaml"  # model config
sam2_model = build_sam2(model_cfg, sam2_checkpoint, device="cuda")  # load model
predictor = SAM2ImagePredictor(sam2_model)

#If saved
# saved_state = torch.load("model_large.torch")
# predictor.model.load_state_dict(saved_state)

# Set training parameters

predictor.model.sam_mask_decoder.train(True)  # enable training of mask decoder
predictor.model.sam_prompt_encoder.train(True)  # enable training of prompt encoder
optimizer = torch.optim.AdamW(params=predictor.model.parameters(), lr=1e-5, weight_decay=4e-5)
scaler = torch.cuda.amp.GradScaler()  # mixed precision

# %%
def check_weight_updates(model, old_state_dict):
    updated = False
    for name, param in model.named_parameters():
        if not torch.equal(param.data, old_state_dict[name].data):
            updated = True
            break
    return updated

# %%
# Training loop

for itr in range(100000):
    with torch.cuda.amp.autocast():  # cast to mix precision
        # Use the custom read_batch function
        image, mask, input_point, input_label = read_reduced_batch(data, image_s3_prefix)  # in a better computer you can run for all the masks

        if mask.shape[0] == 0: continue  # ignore empty batches

        predictor.set_image(image)  # apply SAM image encoder to the image

        # prompt encoding
        mask_input, unnorm_coords, labels, unnorm_box = predictor._prep_prompts(
            input_point, input_label, box=None, mask_logits=None, normalize_coords=True
        )
        sparse_embeddings, dense_embeddings = predictor.model.sam_prompt_encoder(
            points=(unnorm_coords, labels), boxes=None, masks=None,
        )

        # mask decoder
        batched_mode = unnorm_coords.shape[0] > 1  # multi object prediction
        high_res_features = [feat_level[-1].unsqueeze(0) for feat_level in predictor._features["high_res_feats"]]
        low_res_masks, prd_scores, _, _ = predictor.model.sam_mask_decoder(
            image_embeddings=predictor._features["image_embed"][-1].unsqueeze(0),
            image_pe=predictor.model.sam_prompt_encoder.get_dense_pe(),
            sparse_prompt_embeddings=sparse_embeddings,
            dense_prompt_embeddings=dense_embeddings,
            multimask_output=True,
            repeat_image=batched_mode,
            high_res_features=high_res_features,
        )
        prd_masks = predictor._transforms.postprocess_masks(
            low_res_masks, predictor._orig_hw[-1]
        )  # Upscale the masks to the original image resolution

        # Segmentation Loss calculation
        gt_mask = torch.tensor(mask.astype(np.float32)).cuda()
        prd_mask = torch.sigmoid(prd_masks[:, 0])  # Turn logit map to probability map
        seg_loss = (
            -gt_mask * torch.log(prd_mask + 0.00001)
            - (1 - gt_mask) * torch.log((1 - prd_mask) + 0.00001)
        ).mean()  # cross entropy loss

        # Score loss calculation (intersection over union) IOU
        inter = (gt_mask * (prd_mask > 0.5)).sum(1).sum(1)
        iou = inter / (gt_mask.sum(1).sum(1) + (prd_mask > 0.5).sum(1).sum(1) - inter)
        score_loss = torch.abs(prd_scores[:, 0] - iou).mean()
        loss = seg_loss + score_loss * 0.05  # mix losses

        # Save model's current state_dict before the update
        if itr % 1000 == 0:
            old_state_dict = {name: param.clone() for name, param in predictor.model.named_parameters()}

        # apply backpropagation
        predictor.model.zero_grad()  # empty gradient
        scaler.scale(loss).backward()  # Backpropagate
        scaler.step(optimizer)
        scaler.update()  # Mix precision

        # Check if weights have been updated
        if itr % 1000 == 0:
            if check_weight_updates(predictor.model, old_state_dict):
                    print(f"Iteration {itr}: Weights have been updated.")
            else:
                    print(f"Iteration {itr}: No weight updates detected.")

        if itr % 1000 == 0: 
            torch.save(predictor.model.state_dict(), "model.torch")
            print("Model saved.")

        # Display results
        if itr == 0: 
            mean_iou = 0
        mean_iou = mean_iou * 0.99 + 0.01 * np.mean(iou.cpu().detach().numpy())
        print(f"step {itr} Accuracy(IOU)= {mean_iou:.8f}")
# Out:
# Iteration 0: Weights have been updated.
# Model saved.
# step 0 Accuracy(IOU)= 0.00029156
# step 1 Accuracy(IOU)= 0.00687417
# step 2 Accuracy(IOU)= 0.00979572
# step 3 Accuracy(IOU)= 0.01120439
# step 4 Accuracy(IOU)= 0.01787430
# step 5 Accuracy(IOU)= 0.02400235
# step 6 Accuracy(IOU)= 0.03289019
# step 7 Accuracy(IOU)= 0.04027220
# step 8 Accuracy(IOU)= 0.04641215
# step 9 Accuracy(IOU)= 0.05300135
# step 10 Accuracy(IOU)= 0.05599562
# step 11 Accuracy(IOU)= 0.05571440
# step 12 Accuracy(IOU)= 0.05785351
# step 13 Accuracy(IOU)= 0.05957951
# step 14 Accuracy(IOU)= 0.06424029
# step 15 Accuracy(IOU)= 0.07006607
# step 16 Accuracy(IOU)= 0.07283913
# /tmp/ipykernel_7466/2493433692.py:22: RuntimeWarning: invalid value encountered in cast
#   image_normalized = image_normalized.astype(np.uint8)
# step 17 Accuracy(IOU)= 0.07365953
# step 18 Accuracy(IOU)= 0.07938031
# step 19 Accuracy(IOU)= 0.08436776
# step 20 Accuracy(IOU)= 0.08780354
# step 21 Accuracy(IOU)= 0.09496804
# step 22 Accuracy(IOU)= 0.09790447
# step 23 Accuracy(IOU)= 0.10160429
# step 24 Accuracy(IOU)= 0.10616441
# step 25 Accuracy(IOU)= 0.10831610
# step 26 Accuracy(IOU)= 0.11028661
# step 27 Accuracy(IOU)= 0.11519319
# step 28 Accuracy(IOU)= 0.11855484
# step 29 Accuracy(IOU)= 0.11976635
# step 30 Accuracy(IOU)= 0.12289432
# step 31 Accuracy(IOU)= 0.12483348
# step 32 Accuracy(IOU)= 0.12859573
# step 33 Accuracy(IOU)= 0.12935283
# step 34 Accuracy(IOU)= 0.13383566
# step 35 Accuracy(IOU)= 0.13627402
# step 36 Accuracy(IOU)= 0.13900261
# step 37 Accuracy(IOU)= 0.14035317
# step 38 Accuracy(IOU)= 0.14272742
# step 39 Accuracy(IOU)= 0.14203367
# step 40 Accuracy(IOU)= 0.14534209
# step 41 Accuracy(IOU)= 0.14621181
# step 42 Accuracy(IOU)= 0.14651247
# step 43 Accuracy(IOU)= 0.14791806
# step 44 Accuracy(IOU)= 0.14832648
# step 45 Accuracy(IOU)= 0.14920619
# step 46 Accuracy(IOU)= 0.15143519
# step 47 Accuracy(IOU)= 0.15190104
# step 48 Accuracy(IOU)= 0.15383943
# step 49 Accuracy(IOU)= 0.15816090
# step 50 Accuracy(IOU)= 0.15681106
# step 51 Accuracy(IOU)= 0.15903740
# step 52 Accuracy(IOU)= 0.16464972
# step 53 Accuracy(IOU)= 0.16914062
# step 54 Accuracy(IOU)= 0.16953811
# step 55 Accuracy(IOU)= 0.16989578
# step 56 Accuracy(IOU)= 0.16910100
# step 57 Accuracy(IOU)= 0.17554624
# step 58 Accuracy(IOU)= 0.17433594
# step 59 Accuracy(IOU)= 0.17449401
# step 60 Accuracy(IOU)= 0.17488713
# step 61 Accuracy(IOU)= 0.17717281
# step 62 Accuracy(IOU)= 0.17814851
# step 63 Accuracy(IOU)= 0.18174914
# step 64 Accuracy(IOU)= 0.18119466
# step 65 Accuracy(IOU)= 0.18332049
# step 66 Accuracy(IOU)= 0.18802519
# step 67 Accuracy(IOU)= 0.19102479
# step 68 Accuracy(IOU)= 0.18991769
# step 69 Accuracy(IOU)= 0.18859858
# step 70 Accuracy(IOU)= 0.19165044
# step 71 Accuracy(IOU)= 0.19871680
# step 72 Accuracy(IOU)= 0.20232274
# step 73 Accuracy(IOU)= 0.20671435
# step 74 Accuracy(IOU)= 0.21296423
# step 75 Accuracy(IOU)= 0.21291550
# step 76 Accuracy(IOU)= 0.21803175
# step 77 Accuracy(IOU)= 0.22378771
# step 78 Accuracy(IOU)= 0.22327315
# step 79 Accuracy(IOU)= 0.22223809
# step 80 Accuracy(IOU)= 0.22604145
# step 81 Accuracy(IOU)= 0.22766851
# step 82 Accuracy(IOU)= 0.22996721
# step 83 Accuracy(IOU)= 0.23029096
# step 84 Accuracy(IOU)= 0.23422830
# step 85 Accuracy(IOU)= 0.23456477
# step 86 Accuracy(IOU)= 0.24030588
# step 87 Accuracy(IOU)= 0.24472266
# step 88 Accuracy(IOU)= 0.24474676
# step 89 Accuracy(IOU)= 0.24510225
# step 90 Accuracy(IOU)= 0.24381588
# step 91 Accuracy(IOU)= 0.24321595
# step 92 Accuracy(IOU)= 0.24477913
# step 93 Accuracy(IOU)= 0.24302151
# step 94 Accuracy(IOU)= 0.24290437
# step 95 Accuracy(IOU)= 0.24393497
# step 96 Accuracy(IOU)= 0.24238538
# step 97 Accuracy(IOU)= 0.24506999
# step 98 Accuracy(IOU)= 0.24704043
# step 99 Accuracy(IOU)= 0.24707536
# step 100 Accuracy(IOU)= 0.24659700
# step 101 Accuracy(IOU)= 0.24691522
# step 102 Accuracy(IOU)= 0.24508882
# step 103 Accuracy(IOU)= 0.24909337
# step 104 Accuracy(IOU)= 0.24966639
# step 105 Accuracy(IOU)= 0.25108779
# step 106 Accuracy(IOU)= 0.24909613
# step 107 Accuracy(IOU)= 0.25187773
# step 108 Accuracy(IOU)= 0.25411022
# step 109 Accuracy(IOU)= 0.25788907
# step 110 Accuracy(IOU)= 0.25559886
# step 111 Accuracy(IOU)= 0.26085114
# step 112 Accuracy(IOU)= 0.26485005
# step 113 Accuracy(IOU)= 0.26798877
# step 114 Accuracy(IOU)= 0.26853006
# step 115 Accuracy(IOU)= 0.26864570
# step 116 Accuracy(IOU)= 0.27477342
# step 117 Accuracy(IOU)= 0.27530200
# step 118 Accuracy(IOU)= 0.27513580
# step 119 Accuracy(IOU)= 0.27805210
# step 120 Accuracy(IOU)= 0.27936535
# step 121 Accuracy(IOU)= 0.28495166
# step 122 Accuracy(IOU)= 0.28277622
# step 123 Accuracy(IOU)= 0.28030399
# step 124 Accuracy(IOU)= 0.28055621
# step 125 Accuracy(IOU)= 0.28048583
# step 126 Accuracy(IOU)= 0.27929146
# step 127 Accuracy(IOU)= 0.27748379
# step 128 Accuracy(IOU)= 0.28121764
# step 129 Accuracy(IOU)= 0.27983218
# step 130 Accuracy(IOU)= 0.28132012
# step 131 Accuracy(IOU)= 0.28084426
# step 132 Accuracy(IOU)= 0.28339557
# step 133 Accuracy(IOU)= 0.28355592
# step 134 Accuracy(IOU)= 0.28894794
# step 135 Accuracy(IOU)= 0.28778633
# step 136 Accuracy(IOU)= 0.29247216
# step 137 Accuracy(IOU)= 0.29389532
# step 138 Accuracy(IOU)= 0.29375880
# step 139 Accuracy(IOU)= 0.29494902
# step 140 Accuracy(IOU)= 0.29831944
# step 141 Accuracy(IOU)= 0.30211611
# step 142 Accuracy(IOU)= 0.30112040
# step 143 Accuracy(IOU)= 0.29861737
# step 144 Accuracy(IOU)= 0.29674315
# step 145 Accuracy(IOU)= 0.30252918
# step 146 Accuracy(IOU)= 0.30647531
# step 147 Accuracy(IOU)= 0.30804540
# step 148 Accuracy(IOU)= 0.31229458
# step 149 Accuracy(IOU)= 0.31420430
# step 150 Accuracy(IOU)= 0.31302635
# step 151 Accuracy(IOU)= 0.31463205
# step 152 Accuracy(IOU)= 0.31293533
# step 153 Accuracy(IOU)= 0.31039292
# step 154 Accuracy(IOU)= 0.31023979
# step 155 Accuracy(IOU)= 0.31353174
# step 156 Accuracy(IOU)= 0.31320329
# step 157 Accuracy(IOU)= 0.31333081
# step 158 Accuracy(IOU)= 0.31183558
# step 159 Accuracy(IOU)= 0.31774867
# step 160 Accuracy(IOU)= 0.32004270
# step 161 Accuracy(IOU)= 0.32452082
# step 162 Accuracy(IOU)= 0.32251006
# step 163 Accuracy(IOU)= 0.32298428
# step 164 Accuracy(IOU)= 0.32141164
# step 165 Accuracy(IOU)= 0.32219210
# step 166 Accuracy(IOU)= 0.32242029
# step 167 Accuracy(IOU)= 0.31984702
# step 168 Accuracy(IOU)= 0.31804639
# step 169 Accuracy(IOU)= 0.32205989
# step 170 Accuracy(IOU)= 0.32613638
# step 171 Accuracy(IOU)= 0.32564125
# step 172 Accuracy(IOU)= 0.32393133
# step 173 Accuracy(IOU)= 0.32648590
# step 174 Accuracy(IOU)= 0.32595116
# step 175 Accuracy(IOU)= 0.33065594
# step 176 Accuracy(IOU)= 0.33259960
# step 177 Accuracy(IOU)= 0.33076071
# step 178 Accuracy(IOU)= 0.32885140
# step 179 Accuracy(IOU)= 0.33016153
# step 180 Accuracy(IOU)= 0.32871095
# step 181 Accuracy(IOU)= 0.33012394
# step 182 Accuracy(IOU)= 0.32983380
# step 183 Accuracy(IOU)= 0.32740351
# step 184 Accuracy(IOU)= 0.32759987
# step 185 Accuracy(IOU)= 0.32845197
# step 186 Accuracy(IOU)= 0.32752229
# step 187 Accuracy(IOU)= 0.33221562
# step 188 Accuracy(IOU)= 0.33350746
# step 189 Accuracy(IOU)= 0.33148846
# step 190 Accuracy(IOU)= 0.32882373
# step 191 Accuracy(IOU)= 0.33248249
# step 192 Accuracy(IOU)= 0.33324517
# step 193 Accuracy(IOU)= 0.33420617
# step 194 Accuracy(IOU)= 0.33996261
# step 195 Accuracy(IOU)= 0.34053733
# step 196 Accuracy(IOU)= 0.34313082
# step 197 Accuracy(IOU)= 0.34274431
# step 198 Accuracy(IOU)= 0.33982645
# step 199 Accuracy(IOU)= 0.34383097
# step 200 Accuracy(IOU)= 0.34771310
# step 201 Accuracy(IOU)= 0.34520410
# step 202 Accuracy(IOU)= 0.34417731
# step 203 Accuracy(IOU)= 0.34436260
# step 204 Accuracy(IOU)= 0.34642967
# step 205 Accuracy(IOU)= 0.34660975
# step 206 Accuracy(IOU)= 0.35021256
# step 207 Accuracy(IOU)= 0.34968701
# step 208 Accuracy(IOU)= 0.35015264
# step 209 Accuracy(IOU)= 0.34930440
# step 210 Accuracy(IOU)= 0.35308755
# step 211 Accuracy(IOU)= 0.35510139
# step 212 Accuracy(IOU)= 0.35616429
# step 213 Accuracy(IOU)= 0.36080846
# step 214 Accuracy(IOU)= 0.35872879
# step 215 Accuracy(IOU)= 0.35805168
# step 216 Accuracy(IOU)= 0.35827533
# step 217 Accuracy(IOU)= 0.35687273
# step 218 Accuracy(IOU)= 0.35596634
# step 219 Accuracy(IOU)= 0.35605195
# step 220 Accuracy(IOU)= 0.35677524
# step 221 Accuracy(IOU)= 0.35571999
# step 222 Accuracy(IOU)= 0.35884071
# step 223 Accuracy(IOU)= 0.35909072
# step 224 Accuracy(IOU)= 0.35946789
# step 225 Accuracy(IOU)= 0.36291658
# step 226 Accuracy(IOU)= 0.36277579
# step 227 Accuracy(IOU)= 0.36165817
# step 228 Accuracy(IOU)= 0.36400342
# step 229 Accuracy(IOU)= 0.36168509
# step 230 Accuracy(IOU)= 0.36280496
# step 231 Accuracy(IOU)= 0.35989510
# step 232 Accuracy(IOU)= 0.36073943
# step 233 Accuracy(IOU)= 0.35911048
# step 234 Accuracy(IOU)= 0.35877742
# step 235 Accuracy(IOU)= 0.35752153
# step 236 Accuracy(IOU)= 0.36023276
# step 237 Accuracy(IOU)= 0.36300068
# step 238 Accuracy(IOU)= 0.36153317
# step 239 Accuracy(IOU)= 0.36324913
# step 240 Accuracy(IOU)= 0.36431568
# step 241 Accuracy(IOU)= 0.36751538
# step 242 Accuracy(IOU)= 0.36839582
# step 243 Accuracy(IOU)= 0.36575598
# step 244 Accuracy(IOU)= 0.36402723
# step 245 Accuracy(IOU)= 0.36100533
# step 246 Accuracy(IOU)= 0.36243350
# step 247 Accuracy(IOU)= 0.36050442
# step 248 Accuracy(IOU)= 0.36129582
# step 249 Accuracy(IOU)= 0.36392127
# step 250 Accuracy(IOU)= 0.36307925
# step 251 Accuracy(IOU)= 0.36568615
# step 252 Accuracy(IOU)= 0.36836088
# step 253 Accuracy(IOU)= 0.37093980
# step 254 Accuracy(IOU)= 0.37277087
# step 255 Accuracy(IOU)= 0.37494808
# step 256 Accuracy(IOU)= 0.37570651
# step 257 Accuracy(IOU)= 0.37862046
# step 258 Accuracy(IOU)= 0.37668622
# step 259 Accuracy(IOU)= 0.37759291
# step 260 Accuracy(IOU)= 0.37546309

# %%
torch.save(predictor.model.state_dict(), "model.torch")

# %% [markdown]
# ## Test the results

# %%
import matplotlib.pyplot as plt
import torch
import numpy as np

# Function to calculate IoU between two masks
def calculate_iou(gt_mask, pred_mask):
    inter = (gt_mask & pred_mask).sum()
    union = (gt_mask | pred_mask).sum()
    iou = inter / (union + 1e-5)
    return iou.item()

# Function to visualize the image, GT mask, and predicted masks from different models
def visualize_image_and_masks(image, gt_mask, prd_mask_saved, prd_mask_checkpoint, point):
    plt.figure(figsize=(20, 4))

    # Plot image with random point
    plt.subplot(1, 4, 1)
    plt.imshow(image)
    plt.scatter(point[0], point[1], color='red')
    plt.title("Image with Random Point")

    # Plot GT mask
    plt.subplot(1, 4, 2)
    plt.imshow(gt_mask, cmap='gray')
    plt.title("Ground Truth Mask")

    # Plot Predicted mask (Current saved state)
    plt.subplot(1, 4, 3)
    plt.imshow(prd_mask_saved, cmap='gray')
    plt.title("Current Saved State")

    # Plot Predicted mask (SAM2 checkpoint)
    plt.subplot(1, 4, 4)
    plt.imshow(prd_mask_checkpoint, cmap='gray')
    plt.title("SAM2 Checkpoint")

    plt.show()

# Test the read_batch function and visualize the result
image, mask, input_point, input_label = read_reduced_batch(data, image_s3_prefix)

# Use the first point in the batch
input_point = np.array([[500, 375]])
input_label = np.array([1])



# 2. Load the SAM2 checkpoint and predict
sam2_checkpoint = "./segment-anything-2/checkpoints/sam2_hiera_large.pt"  # Adjust to large if needed
model_cfg = "sam2_hiera_l.yaml"  # Adjust to large if needed
sam2_model = build_sam2(model_cfg, sam2_checkpoint, device="cuda")
predictor = SAM2ImagePredictor(sam2_model)
predictor.set_image(image)
masks_pred_checkpoint, _, _ = predictor.predict(
    point_coords=input_point,
    point_labels=input_label,
    multimask_output=False
)
prd_mask_checkpoint = masks_pred_checkpoint[0].astype(np.uint8)

# 1. Load the saved model state and predict
# use bfloat16 for the entire script (memory efficient)
torch.autocast(device_type="cuda", dtype=torch.bfloat16).__enter__()

saved_state = torch.load("model_large.torch")
predictor.model.load_state_dict(saved_state)

with torch.no_grad(): # prevent the net from caclulate gradient (more efficient inference)
        predictor.set_image(image) # image encoder
            # Use the first point in the batch
        input_points = np.array([[500, 375]])
        input_labels = np.array([1])
        masks_pred_saved, _, _ = predictor.predict(
            point_coords=input_point,
            point_labels=input_label,
            multimask_output=False
        )
        prd_mask_saved = masks_pred_saved[0].astype(np.uint8)
      

# Convert ground truth mask to binary
gt_mask = masks[0].astype(np.uint8)

# # Calculate IoU
# iou_saved_state = calculate_iou(gt_mask, prd_mask_saved)
# iou_checkpoint = calculate_iou(gt_mask, prd_mask_checkpoint)

# print(f"IoU (Current Saved State): {iou_saved_state:.4f}")
# print(f"IoU (SAM2 Checkpoint): {iou_checkpoint:.4f}")

# Visualize all the results
visualize_image_and_masks(image, gt_mask, prd_mask_saved, prd_mask_checkpoint, input_points[0])
